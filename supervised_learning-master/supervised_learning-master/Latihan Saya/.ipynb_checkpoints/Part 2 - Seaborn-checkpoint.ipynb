# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../03 - Matplotlib Intro/data/linear.csv")
df.sample(10)
# Out:
#             X         y   tipe
# 98   0.803427  4.398494  data1
# 136  0.137927  0.883517  data2
# 154  0.337045  1.873021  data2
# 15   0.924549  4.571456  data1
# 117  0.237649  1.655083  data2
# 180  0.173863  1.226008  data2
# 13   0.704387  3.811218  data1
# 36   0.591785  3.592048  data1
# 142  0.234676  1.454351  data2
# 145  0.201317  0.959767  data2

# %%
df1 =df[df.tipe == "data1"]
df2 = df[df.tipe == "data2"]
plt.scatter(df1.X, df1.y);
plt.scatter(df2.X, df2.y);

# %% [markdown]
# ### Seaborn

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x="X", y="y", data=df, hue="tipe")
# Out:
# <Axes: xlabel='X', ylabel='y'>

# %%
plt.figure(figsize=(6,6))
sns.lmplot(x="X",y="y", data=df, hue="tipe")
